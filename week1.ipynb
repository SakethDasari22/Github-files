# %%
# Name: Saketh Dasari

# %%
import pandas as pd

# %%
#load thee data
housing_df=pd.read_csv('WestRoxbury.csv')

# %%
#find dimention of data
housing_df.shape
# Out:
# (5802, 14)

# %%
#show me the first five rows
housing_df.head()
# Out:
#    TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  FLOORS   \
# 0         344.2  4330       9965      1880         2436         1352      2.0
# 1         412.6  5190       6590      1945         3108         1976      2.0
# 2         330.1  4152       7500      1890         2294         1371      2.0
# 3         498.6  6272      13773      1957         5032         2608      1.0
# 4         331.5  4170       5000      1910         2370         1438      2.0
#
#    ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE REMODEL
# 0      6          3          1          1        1          0     NaN
# 1     10          4          2          1        1          0  Recent
# 2      8          4          1          1        1          0     NaN
# 3      9          5          1          1        1          1     NaN
# 4      7          3          2          0        1          0     NaN

# %%
#show all the data
print(housing_df)
# Out:
#       TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA  \
# 0            344.2  4330       9965      1880         2436         1352
# 1            412.6  5190       6590      1945         3108         1976
# 2            330.1  4152       7500      1890         2294         1371
# 3            498.6  6272      13773      1957         5032         2608
# 4            331.5  4170       5000      1910         2370         1438
# ...            ...   ...        ...       ...          ...          ...
# 5797         404.8  5092       6762      1938         2594         1714
# 5798         407.9  5131       9408      1950         2414         1333
# 5799         406.5  5113       7198      1987         2480         1674
# 5800         308.7  3883       6890      1946         2000         1000
# 5801         447.6  5630       7406      1950         2510         1600
#
#       FLOORS   ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE  \
# ...

# %%
#rename columns: replace space with '_'
housing_df = housing_df.rename(columns={'TOTAL VALUE': ' TOTAL _ VALUE'})

# %%
housing_df.columns = [s.strip().replace(' ', ' _ ') for s in housing_df.columns]

# %%
#show me the first five rows
housing_df.head()
# Out:
#    TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  LIVING _ AREA  \
# 0          344.2  4330        9965        1880          2436           1352
# 1          412.6  5190        6590        1945          3108           1976
# 2          330.1  4152        7500        1890          2294           1371
# 3          498.6  6272       13773        1957          5032           2608
# 4          331.5  4170        5000        1910          2370           1438
#
#    FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  KITCHEN  FIREPLACE  \
# 0     2.0      6         3            1            1        1          0
# 1     2.0     10         4            2            1        1          0
# 2     2.0      8         4            1            1        1          0
# 3     1.0      9         5            1            1        1          1
# 4     2.0      7         3            2            0        1          0
#
#   REMODEL
# 0     NaN
# 1  Recent
# 2     NaN
# 3     NaN
# 4     NaN

# %%
 #show first four rows of the data
housing_df.loc[0:3]
# Out:
#    TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  LIVING _ AREA  \
# 0          344.2  4330        9965        1880          2436           1352
# 1          412.6  5190        6590        1945          3108           1976
# 2          330.1  4152        7500        1890          2294           1371
# 3          498.6  6272       13773        1957          5032           2608
#
#    FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  KITCHEN  FIREPLACE  \
# 0     2.0      6         3            1            1        1          0
# 1     2.0     10         4            2            1        1          0
# 2     2.0      8         4            1            1        1          0
# 3     1.0      9         5            1            1        1          1
#
#   REMODEL
# 0     NaN
# 1  Recent
# 2     NaN
# 3     NaN

# %%
#not including the last row number
housing_df.iloc[0:4]
# Out:
#    TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  LIVING _ AREA  \
# 0          344.2  4330        9965        1880          2436           1352
# 1          412.6  5190        6590        1945          3108           1976
# 2          330.1  4152        7500        1890          2294           1371
# 3          498.6  6272       13773        1957          5032           2608
#
#    FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  KITCHEN  FIREPLACE  \
# 0     2.0      6         3            1            1        1          0
# 1     2.0     10         4            2            1        1          0
# 2     2.0      8         4            1            1        1          0
# 3     1.0      9         5            1            1        1          1
#
#   REMODEL
# 0     NaN
# 1  Recent
# 2     NaN
# 3     NaN

# %%
#different ways of showing the 10 rows for a varible 
housing_df['TOTAL _ VALUE'].iloc[0:10]
# Out:
# 0    344.2
# 1    412.6
# 2    330.1
# 3    498.6
# 4    331.5
# 5    337.4
# 6    359.4
# 7    320.4
# 8    333.5
# 9    409.4
# Name: TOTAL _ VALUE, dtype: float64

# %%
housing_df.iloc[0:10]['TOTAL _ VALUE']
# Out:
# 0    344.2
# 1    412.6
# 2    330.1
# 3    498.6
# 4    331.5
# 5    337.4
# 6    359.4
# 7    320.4
# 8    333.5
# 9    409.4
# Name: TOTAL _ VALUE, dtype: float64

# %%
#show the fifth row of 10 columns
housing_df.iloc[3] [0:10]
# Out:
# TOTAL _ VALUE    498.6
# TAX               6272
# LOT _ SQFT       13773
# YR _ BUILT        1957
# GROSS _ AREA      5032
# LIVING _ AREA     2608
# FLOORS             1.0
# ROOMS                9
# BEDROOMS             5
# FULL _ BATH          1
# Name: 3, dtype: object

# %%
housing_df.iloc[4:5, 0:10]
# Out:
#    TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  LIVING _ AREA  \
# 4          331.5  4170        5000        1910          2370           1438
#
#    FLOORS  ROOMS  BEDROOMS  FULL _ BATH
# 4     2.0      7         3            2

# %%
#Data exploration
pd.concat([housing_df.iloc[4:6, 0:2], housing_df.iloc[4:6, 4:6]], axis=1)
# Out:
#    TOTAL _ VALUE   TAX  GROSS _ AREA  LIVING _ AREA
# 4          331.5  4170          2370           1438
# 5          337.4  4244          2124           1060

# %%
# showing all the columns
housing_df.iloc[:, 0:1]
# Out:
#       TOTAL _ VALUE
# 0             344.2
# 1             412.6
# 2             330.1
# 3             498.6
# 4             331.5
# ...             ...
# 5797          404.8
# 5798          407.9
# 5799          406.5
# 5800          308.7
# 5801          447.6
#
# [5802 rows x 1 columns]

# %%
#Descriptive statistics

# %%
#showing you the length of first column
print('Number of rows', len(housing_df['TOTAL _ VALUE']))
# Out:
# Number of rows 5802

# %%
print('Mean of TOTAL_VALUE', housing_df['TOTAL _ VALUE'].mean())
# Out:
# Mean of TOTAL_VALUE 392.6857149258877

# %%
#showing the summary statistics for each column
housing_df.describe()
# Out:
#        TOTAL _ VALUE           TAX    LOT _ SQFT   YR _ BUILT  GROSS _ AREA  \
# count    5802.000000   5802.000000   5802.000000  5802.000000   5802.000000
# mean      392.685715   4939.485867   6278.083764  1936.744916   2924.842123
# std        99.177414   1247.649118   2669.707974    35.989910    883.984726
# min       105.000000   1320.000000    997.000000     0.000000    821.000000
# 25%       325.125000   4089.500000   4772.000000  1920.000000   2347.000000
# 50%       375.900000   4728.000000   5683.000000  1935.000000   2700.000000
# 75%       438.775000   5519.500000   7022.250000  1955.000000   3239.000000
# max      1217.800000  15319.000000  46411.000000  2011.000000   8154.000000
#
#        LIVING _ AREA       FLOORS        ROOMS     BEDROOMS  FULL _ BATH  \
# count    5802.000000  5802.000000  5802.000000  5802.000000  5802.000000
# mean     1657.065322     1.683730     6.994829     3.230093     1.296794
# ...

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression

# %%
#random sampling 
housing_df.sample(5)
# Out:
#       TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  \
# 727           330.3  4155       16000        1925          3124
# 1800          348.0  4377        4794        1925          3154
# 5514          386.8  4865        5000        1940          2667
# 55            345.9  4351        8005        1900          2490
# 125           442.6  5567        4800        1999          3960
#
#       LIVING _ AREA  FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  \
# 727            1430     1.0      7         3            1            1
# 1800           1976     2.0      7         4            1            1
# 5514           1566     2.0      7         4            1            1
# 55             1562     2.0      7         3            1            1
# 125            2282     2.0      6         3            2            1
#
#       KITCHEN  FIREPLACE REMODEL
# 727         1          0     NaN
# 1800        1          0     Old
# 5514        1          0     Old
# ...

# %%
#oversample
weights = [0.9 if rooms> 10 else 0.1 for rooms in housing_df.ROOMS]

# %%
housing_df.sample(5, weights=weights)
# Out:
#       TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  \
# 5521          374.3  4708        8134        1940          3756
# 1269          318.6  4007        4816        1920          2013
# 455           325.7  4097        6895        1960          2066
# 2687          397.1  4995        5000        1910          3014
# 3493          333.2  4191        5000        1923          2528
#
#       LIVING _ AREA  FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  \
# 5521           1427     1.0      6         2            1            0
# 1269           1232     2.0      7         3            1            2
# 455            1966     1.0      7         3            1            1
# 2687           1878     2.0     11         6            2            0
# 3493           1269     1.5      6         3            1            1
#
#       KITCHEN  FIREPLACE REMODEL
# 5521        1          1     NaN
# 1269        1          1     NaN
# 455         1          0     NaN
# ...

# %%
housing_df.sample(5, weights=weights)
# Out:
#       TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  \
# 2517          493.1  6203       11310        1918          3524
# 5243          396.4  4986        5708        1950          2649
# 4583          353.3  4444        6297        1940          2036
# 5248          352.6  4435        5000        1930          2608
# 5641          318.0  4000        4026        1940          2700
#
#       LIVING _ AREA  FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  \
# 2517           1990     2.0      7         3            1            1
# 5243           1494     2.0      7         3            1            1
# 4583           1291     2.0      7         3            2            0
# 5248           1584     2.0      8         3            1            0
# 5641           1461     2.0      6         3            1            1
#
#       KITCHEN  FIREPLACE REMODEL
# 2517        1          1     NaN
# 5243        1          1     NaN
# 4583        1          1     NaN
# ...

# %%
housing_df.columns
# Out:
# Index(['TOTAL _ VALUE', 'TAX', 'LOT _ SQFT', 'YR _ BUILT', 'GROSS _ AREA',
#        'LIVING _ AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL _ BATH',
#        'HALF _ BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
#changin the ROMODEL to categorical type of variables.
housing_df.REMODEL = housing_df.REMODEL.astype('category')

# %%
housing_df.REMODEL.cat.categories
# Out:
# Index(['Old', 'Recent'], dtype='object')

# %%
housing_df.REMODEL.dtype
# Out:
# CategoricalDtype(categories=['Old', 'Recent'], ordered=False, categories_dtype=object)

# %%
#use drop first of the REMODEL variable
housing_df = pd.get_dummies(housing_df, prefix_sep = '_', drop_first =True)

# %%
housing_df.columns
# Out:
# Index(['TOTAL _ VALUE', 'TAX', 'LOT _ SQFT', 'YR _ BUILT', 'GROSS _ AREA',
#        'LIVING _ AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL _ BATH',
#        'HALF _ BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL_Recent'],
#       dtype='object')

# %%
missingRows = housing_df.sample(10).index

# %%
medianBedrooms = housing_df ['BEDROOMS']. median()

# %%
housing_df.BEDROOMS = housing_df.BEDROOMS.fillna(value=medianBedrooms)

# %%
print ('Number or rows with valid BEDROOMS:',housing_df['BEDROOMS'].count())
# Out:
# Number or rows with valid BEDROOMS: 5802

# %%
#normalization
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = housing_df.copy()

# %%
#pandas
norm_df = (housing_df - housing_df.mean())/housing_df.std()

# %%
#sckikit-learr
scaler = StandardScaler()

# %%
norm_df= pd.DataFrame(scaler.fit_transform(housing_df), index= housing_df.index, columns=housing_df.columns)

# %%
# scikit-learn:
scaler = MinMaxScaler()
norm_df = pd.DataFrame(scaler.fit_transform(housing_df),index=housing_df.index, columns=housing_df.columns)

# %%
# training (60%) and validation (40%)
trainData, validData = train_test_split(housing_df, test_size=0.40, random_state=1)

# %%
print(trainData)
# Out:
#       TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  \
# 2024          392.0  4931        5750        1937          2568
# 5140          476.3  5991        5500        1925          2936
# 5259          367.4  4621        5000        1922          2616
# 421           350.3  4406        4654        1890          3256
# 1401          348.1  4379        7680        1960          2383
# ...             ...   ...         ...         ...           ...
# 905           371.5  4673       11754        1950          3045
# 5192          333.6  4196        5120        1928          2244
# 3980          404.8  5092        5107        1920          3020
# 235           325.0  4088        3850        1910          2235
# 5157          374.3  4708        5000        1940          2117
#
#       LIVING _ AREA  FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  \
# 2024           1576     2.0      7         3            1            1
# ...

# %%
trainData, temp = train_test_split(housing_df, test_size=0.5, random_state=1)

# %%
# now split temp into validation and test
validData, testData = train_test_split(temp, test_size=0.4, random_state=1)

# %%
print (temp)
# Out:
#       TOTAL _ VALUE   TAX  LOT _ SQFT  YR _ BUILT  GROSS _ AREA  \
# 1822          462.0  5811        5426        1989          2528
# 1998          370.4  4659        5239        1930          2534
# 5126          407.4  5125        7926        1941          2544
# 808           316.1  3976        4730        1910          3243
# 4034          393.2  4946        5757        1910          3728
# ...             ...   ...         ...         ...           ...
# 1327          380.9  4791        6458        1950          3000
# 4262          440.1  5536       10342        1925          2488
# 4383          384.3  4834        4196        1920          2872
# 1255          425.3  5350        6303        1989          2820
# 4722          477.3  6004        6694        1935          3822
#
#       LIVING _ AREA  FLOORS  ROOMS  BEDROOMS  FULL _ BATH  HALF _ BATH  \
# 1822           1600     2.0      7         3            2            1
# ...

# %%
##################END#################################
